# %%
import os
import pandas as pd
import numpy as np

# %%
# %%time
df20191 = pd.read_csv("../SimpleData/2019-1.csv", delimiter = "|")

# %%
df20191.columns
# Out:
# Index(['TIPO_ID_APORTANTE', 'ID_APORTANTE', 'PLANILLA', 'COTIZANTES',
#        'PERIODO_COTIZACION', 'PERIODO_SERVICIO', 'MODALIDAD', 'TIPO_APORTE',
#        'TIPO_PLANILLA', 'FECHA_PAGO', 'VALOR_PLANILLA', 'COD_MUNICIPIO',
#        'CLASE_APORTANTE', 'ACT_ECONOMICA'],
#       dtype='object')

# %%
df20191
# Out:
#         TIPO_ID_APORTANTE  ID_APORTANTE    PLANILLA  COTIZANTES  \
# 0                      NI     805011074  1017493516         458
# 1                      NI     805011074  1017834993           1
# 2                      NI     805011074  1018937061         484
# 3                      NI     805011074  1019701591         500
# 4                      NI     805011074  1020258009         528
# ...                   ...           ...         ...         ...
# 2457020                CC    1151937363  1022068425           1
# 2457021                CC      31579855  1021280966           1
# 2457022                CC      31640203  1018016165           1
# 2457023                CC      31640203  1018016943           1
# 2457024                CC    1143944385  1018992372           1
#
#          PERIODO_COTIZACION  PERIODO_SERVICIO    MODALIDAD TIPO_APORTE  \
# 0                    201812            201901  ELECTRONICA      ACTIVO
# ...

# %%
df20191.groupby("MODALIDAD").count().head()
# Out:
#              TIPO_ID_APORTANTE  ID_APORTANTE  PLANILLA  COTIZANTES  \
# MODALIDAD
# ASISTIDA               1610565       1610565   1610565     1610565
# ELECTRONICA             846460        846460    846460      846460
#
#              PERIODO_COTIZACION  PERIODO_SERVICIO  TIPO_APORTE  TIPO_PLANILLA  \
# MODALIDAD
# ASISTIDA                1610565           1610565      1610565        1610565
# ELECTRONICA              846460            846460       846460         846460
#
#              FECHA_PAGO  VALOR_PLANILLA  COD_MUNICIPIO  CLASE_APORTANTE  \
# MODALIDAD
# ASISTIDA        1610565         1610565        1610565          1610565
# ELECTRONICA      846460          846460         846460           846460
#
#              ACT_ECONOMICA
# MODALIDAD
# ASISTIDA           1610565
# ELECTRONICA         846460

# %%
# %%time
df20192 = pd.read_csv("../data/2019-2.csv", delimiter = "|")
# Out:
# CPU times: user 3.29 s, sys: 509 ms, total: 3.8 s
# Wall time: 3.81 s

# %%
df20192.columns
# Out:
# Index(['TIPO_ID_APORTANTE', 'ID_APORTANTE', 'PLANILLA', 'COTIZANTES',
#        'PERIODO_COTIZACION', 'PERIODO_SERVICIO', 'MODALIDAD', 'TIPO_APORTE',
#        'TIPO_PLANILLA', 'FECHA_PAGO', 'VALOR_PLANILLA', 'COD_MUNICIPIO',
#        'CLASE_APORTANTE', 'ACT_ECONOMICA'],
#       dtype='object')

# %%
df20192
# Out:
#         TIPO_ID_APORTANTE  ID_APORTANTE    PLANILLA  COTIZANTES  \
# 0                      NI     805011074  1022450865         582
# 1                      NI     805011074  1022523197           1
# 2                      NI     805011074  1022526131           1
# 3                      NI     805011074  1023014882          34
# 4                      NI     805011074  1023015316          28
# ...                   ...           ...         ...         ...
# 2650193                CC       3599597  1023041734           1
# 2650194                CC       3599597  1023041786           1
# 2650195                CC       3599597  1024444732           1
# 2650196                CC       3599597  1025252516           1
# 2650197                CC       3599597  1025850589           1
#
#          PERIODO_COTIZACION  PERIODO_SERVICIO    MODALIDAD TIPO_APORTE  \
# 0                    201906            201907  ELECTRONICA      ACTIVO
# ...

# %%
# %%time
df20201 = pd.read_csv("../data/2020-1.csv", delimiter = "|")
# Out:
# <string>:2: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 3.34 s, sys: 386 ms, total: 3.72 s
# Wall time: 3.79 s

# %%
df20201.columns
# Out:
# Index(['TIPO_ID_APORTANTE', 'ID_APORTANTE', 'PLANILLA', 'COTIZANTES',
#        'PERIODO_COTIZACION', 'PERIODO_SERVICIO', 'MODALIDAD', 'TIPO_APORTE',
#        'TIPO_PLANILLA', 'FECHA_PAGO', 'VALOR_PLANILLA', 'COD_MUNICIPIO',
#        'CLASE_APORTANTE', 'ACT_ECONOMICA'],
#       dtype='object')

# %%
df20201
# Out:
#         TIPO_ID_APORTANTE ID_APORTANTE    PLANILLA  COTIZANTES  \
# 0                      NI    805011074  1026153323           1
# 1                      NI    805011074  1026705961         627
# 2                      NI      2727586  1026379611           1
# 3                      NI      2727586  1027270543           1
# 4                      NI      2727586  1027928580           1
# ...                   ...          ...         ...         ...
# 2492690                CC   1143456065  1028690578           1
# 2492691                CC     43434583  1029142419           1
# 2492692                CC     43434583  1029924259           1
# 2492693                CC     79304320  1026765159           1
# 2492694                CC   1075658160  1026764894           1
#
#          PERIODO_COTIZACION  PERIODO_SERVICIO    MODALIDAD TIPO_APORTE  \
# 0                    201911            201912  ELECTRONICA      ACTIVO
# ...
